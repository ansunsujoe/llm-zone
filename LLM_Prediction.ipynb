# %% [markdown]
# <a href="https://colab.research.google.com/github/ansunsujoe/llm-zone/blob/1-query-from-open-source-llm/LLM_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install "accelerate>=0.16.0,<1" "transformers[torch]>=4.28.1,<5" "torch>=1.13.1"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 21.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 56.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.5 MB/s eta 0:00:00
# ...

# %%
from enum import Enum

import torch
from transformers import pipeline


class LLMType(str, Enum):
    DOLLY = "databricks/dolly-v2-3b"


class Model:
    def __init__(self, llm_type: LLMType):
        self.llm_type = llm_type
        self.generator = pipeline(
            model=llm_type.value,
            torch_dtype=torch.bfloat16,
            trust_remote_code=True,
            device_map="auto",
        )

    def generate(self, prompt: str) -> str:
        response = self.generator(prompt)
        return response[0]["generated_text"]

# %%
model = Model(llm_type=LLMType.DOLLY)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/databricks/dolly-v2-3b:
# - instruct_pipeline.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
model.generate("Explain fission.")
# Out:
# "Fission occurs when the nucleus in an atom splits into two smaller nuclei. This occurs when high-energy particles hit the atom, causing it to lose energy and splitting up. Fission is responsible for the creation of nuclear energy, which powers the world's atomic weapons. Fission is also how we create the atoms that make up the elements like hydrogen and carbon that make our bodies and everything around us."
